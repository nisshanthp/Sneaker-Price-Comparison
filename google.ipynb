# %%
import requests
import json

# Set the query parameters
params = {
  "api_key": "c7b106022c885417564cc937c5eb169acfb8b0570b84b9112e8cc6911e8bad3e",
  "engine": "google",
  "q": "Male Air Force 1 Size 9.5",
  "tbm": "shop",
}

# Send the request to the API
response = requests.get("https://serpapi.com/search", params=params)

# Get the shopping results from the response
shopping_results = response.json().get("shopping_results", [])

# Print the shopping results
print(json.dumps(shopping_results, indent=4))
# Out:
# [
#     {
#         "position": 1,
#         "title": "Nike Air Force 1 Sneaker in White/White/White at Nordstrom, Size 11 M",
#         "link": "https://www.nordstrom.com/s/3957860?color=WHITE%2F+WHITE%2F+WHITE&country=US&currency=USD&utm_source=google&utm_medium=organic&utm_campaign=seo_shopping&utm_channel=low_nd_seo_shopping&srsltid=Ad5pg_Fx1z0x4NUQJUX7At8ki-8MSa9IyYj-O6vXgdYycUDtPNDRYabeUT4",
#         "source": "Nordstrom",
#         "price": "$65.00",
#         "extracted_price": 65.0,
#         "rating": 4.3,
#         "reviews": 26,
#         "badge": "Trusted store",
#         "thumbnail": "https://encrypted-tbn2.gstatic.com/shopping?q=tbn:ANd9GcTBxLm5L73-XInTMuT1kcKAv8mbTq9sc4mBOuOQ0Fu2AwckIU-T57NdFjiMq7hTHmN1ol7kTbaotw&usqp=CAE",
#         "delivery": "Free delivery by Mar 31 & Free lifetime returns",
#         "store_rating": 4.8,
#         "store_reviews": 272
#     },
#     {
#         "position": 2,
#         "title": "Nike Air Force 1 '07 White 9.5",
# ...
